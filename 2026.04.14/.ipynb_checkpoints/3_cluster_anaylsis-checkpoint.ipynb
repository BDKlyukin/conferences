# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import BisectingKMeans
from scipy.stats import kendalltau, pearsonr, spearmanr

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import time

# %%
import warnings    
warnings.simplefilter('ignore', np.RankWarning)

# %% [markdown]
# # Importing and formatting data

# %%
WDI_GFDI_df = pd.read_excel(r"data\WDI_GFDI_calculated.xlsx")

# %%
WDI_GFDI_df.dropna(subset=['Growth rate'
                           , 'Economy size'
                           , 'Deposits to GDP'
                           , 'Broad money'
                           , 'Credit to private'
                           , 'Value-traded'
                           , 'Turnover'
                           , 'MarCap to GDP'
                              ]
                      , inplace = True)

# %% [markdown]
# # Vizualizing the Years for which there is data for a country

# %%
# Initialize figure and axis
sns.set_theme(style="whitegrid", palette=None, font_scale=0.9)
fig, ax = plt.subplots(figsize=(9, 13))

# plotting each year where countries are present
n = 0
for country in WDI_GFDI_df.sort_values(by=['Country Name'])['Country Name'].unique():
    time_line_df = WDI_GFDI_df[WDI_GFDI_df['Country Name'] == country][['Country Name', 'Year']]
    time_line_df['Year'] = time_line_df['Year']-0.5
    time_line_df['Length'] = 1
    n += 1
    ax.broken_barh(time_line_df[['Year', 'Length']].values.tolist(), (-1.2 + n, 0.7))

# Set y-ticks and labels
ax.set_yticks(range(len(WDI_GFDI_df.sort_values(by=['Country Name'])['Country Name'].unique())),
              labels=list(WDI_GFDI_df.sort_values(by=['Country Name'])['Country Name'].unique()))
ax.invert_yaxis()  # Invert y-axis for better visualization
ax.set_ylabel("Country Name")  # Label for the x-axis

# Set x-ticks and labels
min_year = min(WDI_GFDI_df.sort_values(by=['Year'])['Year'].unique())
max_year = max(WDI_GFDI_df.sort_values(by=['Year'])['Year'].unique())
ax.set_xticks(range(min_year, max_year+1))
ax.set_xlim(min_year-1,
            max_year+1
           )
plt.xticks(rotation=45)
ax.set_xlabel("Year")  # Label for the x-axis

# setting the title
# ax.set_title("Years for which there is data for a country")

# Display the graph
plt.show()

# %% [markdown]
# # cluster analysis

# %% [markdown]
# ## prepping the df

# %%
financail_development_df = pd.DataFrame()
financail_development_clusters_df = pd.DataFrame()

# selecting the stock market activity indicators
wh1 = WDI_GFDI_df[['Growth rate'
                   , 'Economy size'
                   
                   , 'Broad money'
                   , 'Deposits to GDP'
                   , 'Credit to private'
                   
                   , 'MarCap to GDP'
                   , 'Value-traded'
                   , 'Turnover'
                  ]].dropna()

# %%
# z score standardization
z_score_df = (wh1 - wh1.mean())/wh1.std(ddof = 1)

# %% [markdown]
# ## baseline cluster analysis

# %%
from sklearn.mixture import GaussianMixture

gm_bic= []
gm_aic= []
gm_score=[]
for i in range(2,26):
    gm = GaussianMixture(n_components=i
                         , covariance_type='spherical'
                         , tol=0.0001
                         , reg_covar=1e-06
                         , max_iter=1000
                         , n_init=1000
                         , init_params='k-means++'
                         , weights_init=None
                         , means_init=None
                         , precisions_init=None
                         , random_state=None
                         , warm_start=False
                         , verbose=0
                         , verbose_interval=10
                        ).fit(z_score_df)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(z_score_df)))
    # print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(z_score_df)))
    print("-"*100)
    gm_bic.append(gm.bic(z_score_df))
    gm_aic.append(gm.aic(z_score_df))
    gm_score.append(gm.score(z_score_df))
# Out:
# BIC for number of cluster(s) 2: 26461.3976878619
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 23734.087006570848
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 22148.542094877477
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 21324.004546167842
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 20457.58158075745
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 19878.06256157822
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 19314.463905433622
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 18902.313353069854
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 18386.081984054388
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 18002.917296688298
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 17766.447510725553
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 17417.65914887999
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 17275.254630237243
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 17049.88679566033
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 16820.008657777293
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 16693.369924576888
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 16540.14989622964
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 16443.77619401809
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 16301.735681584109
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 16126.20684320531
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 16128.658762791207
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 16020.774208698043
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 15919.34758223114
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 15863.953422623732
# ----------------------------------------------------------------------------------------------------

# %%
gm_bic_df = pd.DataFrame((gm_bic - min(gm_bic))/(max(gm_bic) - min(gm_bic)), columns=['base_line'])
gm_aic_df = pd.DataFrame((gm_aic - min(gm_aic))/(max(gm_aic) - min(gm_aic)), columns=['base_line'])
gm_score_df = pd.DataFrame((gm_score - min(gm_score))/(max(gm_score) - min(gm_score)), columns=['base_line'])

# %%
gm_bic_df = gm_bic_df.reset_index(drop=False)
gm_bic_df['index'] = gm_bic_df['index']+2
gm_bic_df.rename(columns={'index':'number_of_clusters'
                          }
                , inplace = True)

gm_aic_df = gm_aic_df.reset_index(drop=False)
gm_aic_df['index'] = gm_aic_df['index']+2
gm_aic_df.rename(columns={'index':'number_of_clusters'
                          }
                , inplace = True)

gm_score_df = gm_score_df.reset_index(drop=False)
gm_score_df['index'] = gm_score_df['index']+2
gm_score_df.rename(columns={'index':'number_of_clusters'
                          }
                , inplace = True)

# %%
plt.scatter(x=gm_bic_df['number_of_clusters'],y=gm_bic_df['base_line'],s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Gaussian mixture BIC score")
plt.show()

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_best = PCA(n_components='mle'
                  ,svd_solver='full'
                 )

pca_best.fit(z_score_df)
# Out:
# PCA(n_components='mle', svd_solver='full')

# %%
PCA_loadings_df = pd.DataFrame(data=pca_best.components_.T, columns=['PC_'+str(i) for i in range(1,8)]).T

# %%
PCA_loadings_df.columns = z_score_df.columns

# %%
PCA_loadings_df.to_excel(r"cluster_analysis\PCA_loadings_df.xlsx", index=False)

# %%
pca_explained_var = pca_best.explained_variance_ratio_
cum_explaiend_var = pca_explained_var.cumsum()
cum_explaiend_var = pd.DataFrame(pd.Series(data=cum_explaiend_var, index=PCA_loadings_df.index)).T
cum_explaiend_var.to_excel(r"cluster_analysis\cumulutive_explaiend_var.xlsx", index=False)

# %%
plt.figure(figsize=(12,5))
plt.bar(x=cum_explaiend_var.columns
        , height=cum_explaiend_var.iloc[0]
        , width=0.6
       )
plt.xticks(fontsize=14)
plt.hlines(y=0.8
           , xmin='PC_1'
           , xmax='PC_7'
           , linestyles='dashed'
           , lw=3,colors='black'
          )
plt.text(x='PC_1'
         , y=0.82
         , s="80% variance explained"
         , fontsize=15
        )
plt.show()

# %%
X_pca = pca_best.fit_transform(z_score_df)

# %%
pca_df=pd.DataFrame(data=X_pca,columns=['PC_'+str(i) for i in range(1,8)])

# %%
pca_df.to_excel(r"cluster_analysis\PCA_transformed_data.xlsx", index=False)

# %% [markdown]
# ## finding the best number of PCs to use for clustering

# %%
for col in range(len(pca_df.columns)-1):
    # print(pca_df[pca_df.columns[:col+2]].columns[-1])
    # print(pca_df[pca_df.columns[:col+2]].head())
    
    gm_bic= []
    gm_aic= []
    gm_score=[]
    for i in range(2,26):
        gm = GaussianMixture(n_components=i
                             , covariance_type='spherical'
                             , tol=1e-3
                             , reg_covar=1e-06
                             , max_iter=1000
                             , n_init=1000
                             , init_params='k-means++'
                             , weights_init=None
                             , means_init=None
                             , precisions_init=None
                             , random_state=None
                             , warm_start=False
                             , verbose=0
                             , verbose_interval=10
                            ).fit(pca_df[pca_df.columns[:col+2]])
        print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(pca_df[pca_df.columns[:col+2]])))
        print("AIC for number of cluster(s) {}: {}".format(i,gm.aic(pca_df[pca_df.columns[:col+2]])))
        print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(pca_df[pca_df.columns[:col+2]])))
        print("-"*100)
        gm_bic.append(gm.bic(pca_df[pca_df.columns[:col+2]]))
        gm_aic.append(gm.aic(pca_df[pca_df.columns[:col+2]]))
        gm_score.append(gm.score(pca_df[pca_df.columns[:col+2]]))
    
    temp_gm_bic_df = pd.DataFrame((gm_bic - min(gm_bic))/(max(gm_bic) - min(gm_bic)), columns=[pca_df[pca_df.columns[:col+2]].columns[-1]])
    temp_gm_aic_df = pd.DataFrame((gm_aic - min(gm_aic))/(max(gm_aic) - min(gm_aic)), columns=[pca_df[pca_df.columns[:col+2]].columns[-1]])
    temp_gm_score_df = pd.DataFrame((gm_score - min(gm_score))/(max(gm_score) - min(gm_score)), columns=[pca_df[pca_df.columns[:col+2]].columns[-1]])

    gm_bic_df = pd.concat([gm_bic_df, temp_gm_bic_df], axis=1)
    gm_aic_df = pd.concat([gm_aic_df, temp_gm_aic_df], axis=1)
    gm_score_df = pd.concat([gm_score_df, temp_gm_score_df], axis=1)
# Out:
# BIC for number of cluster(s) 2: 9604.217822901985
# AIC for number of cluster(s) 2: 9566.923359133034
# Log-likelihood score for number of cluster(s) 2: -3.1382796843406813
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 8902.06594592779
# AIC for number of cluster(s) 3: 8843.460360005152
# Log-likelihood score for number of cluster(s) 3: -2.8979830354813245
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 8739.252152487747
# AIC for number of cluster(s) 4: 8659.335444411423
# Log-likelihood score for number of cluster(s) 4: -2.8348670973756316
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 8656.491635997969
# AIC for number of cluster(s) 5: 8555.263805767958
# Log-likelihood score for number of cluster(s) 5: -2.798049870488817
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 8564.032309438093
# AIC for number of cluster(s) 6: 8441.493357054394
# Log-likelihood score for number of cluster(s) 6: -2.7580464379285132
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 8515.186550510189
# AIC for number of cluster(s) 7: 8371.336475972805
# Log-likelihood score for number of cluster(s) 7: -2.732370721410251
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 8516.839362334431
# AIC for number of cluster(s) 8: 8351.67816564336
# Log-likelihood score for number of cluster(s) 8: -2.7232845485030746
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 8517.812757201824
# AIC for number of cluster(s) 9: 8331.340438357067
# Log-likelihood score for number of cluster(s) 9: -2.713975176858432
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 8526.834021307364
# AIC for number of cluster(s) 10: 8319.05058030892
# Log-likelihood score for number of cluster(s) 10: -2.7073096518754665
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 8538.135759925857
# AIC for number of cluster(s) 11: 8309.041196773727
# Log-likelihood score for number of cluster(s) 11: -2.701393297231842
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 8552.511502703806
# AIC for number of cluster(s) 12: 8302.105817397989
# Log-likelihood score for number of cluster(s) 12: -2.6964867994080124
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 8565.674992082497
# AIC for number of cluster(s) 13: 8293.958184622994
# Log-likelihood score for number of cluster(s) 13: -2.6911820580233226
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 8587.075252925359
# AIC for number of cluster(s) 14: 8294.047323312168
# Log-likelihood score for number of cluster(s) 14: -2.688583220536192
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 8610.40826828393
# AIC for number of cluster(s) 15: 8296.069216517055
# Log-likelihood score for number of cluster(s) 15: -2.68661932211467
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 8624.679882421773
# AIC for number of cluster(s) 16: 8289.02970850121
# Log-likelihood score for number of cluster(s) 16: -2.681678616459005
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 8641.578588085034
# AIC for number of cluster(s) 17: 8284.617292010786
# Log-likelihood score for number of cluster(s) 17: -2.6776009500692464
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 8667.332343643846
# AIC for number of cluster(s) 18: 8289.05992541591
# Log-likelihood score for number of cluster(s) 18: -2.67643230138499
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 8680.35237116117
# AIC for number of cluster(s) 19: 8280.768830779549
# Log-likelihood score for number of cluster(s) 19: -2.67108043061089
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 8706.410316199685
# AIC for number of cluster(s) 20: 8285.515653664375
# Log-likelihood score for number of cluster(s) 20: -2.6700117127675345
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 8729.500932161582
# AIC for number of cluster(s) 21: 8287.295147472585
# Log-likelihood score for number of cluster(s) 21: -2.6679681824811388
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 8748.592653702288
# AIC for number of cluster(s) 22: 8285.075746859606
# Log-likelihood score for number of cluster(s) 22: -2.664610954947308
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 8765.139087125553
# AIC for number of cluster(s) 23: 8280.311058129186
# Log-likelihood score for number of cluster(s) 23: -2.6604175618032806
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 8783.911380098783
# AIC for number of cluster(s) 24: 8277.772228948728
# Log-likelihood score for number of cluster(s) 24: -2.6569553971579265
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 8802.660689774479
# AIC for number of cluster(s) 25: 8275.210416470738
# Log-likelihood score for number of cluster(s) 25: -2.653485682152016
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 2: 13971.18765173059
# AIC for number of cluster(s) 2: 13923.237626884795
# Log-likelihood score for number of cluster(s) 2: -4.568080692143494
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 13390.712685333867
# AIC for number of cluster(s) 3: 13316.123757795964
# Log-likelihood score for number of cluster(s) 3: -4.365349460511157
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 13167.78683216583
# AIC for number of cluster(s) 4: 13066.559001935819
# Log-likelihood score for number of cluster(s) 4: -4.280078515747641
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 12966.962178058806
# AIC for number of cluster(s) 5: 12839.095445136687
# Log-likelihood score for number of cluster(s) 5: -4.202068148862249
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 12800.007902192721
# AIC for number of cluster(s) 6: 12645.502266578495
# Log-likelihood score for number of cluster(s) 6: -4.1351847130678365
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 12668.693877921696
# AIC for number of cluster(s) 7: 12487.549339615362
# Log-likelihood score for number of cluster(s) 7: -4.0800096385070175
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 12614.880349202524
# AIC for number of cluster(s) 8: 12407.09690820408
# Log-likelihood score for number of cluster(s) 8: -4.050294647898843
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 12497.523119188485
# AIC for number of cluster(s) 9: 12263.100775497933
# Log-likelihood score for number of cluster(s) 9: -3.9997045911622644
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 12437.997137757351
# AIC for number of cluster(s) 10: 12176.935891374691
# Log-likelihood score for number of cluster(s) 10: -3.968112973513368
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 12392.993432633619
# AIC for number of cluster(s) 11: 12105.29328355885
# Log-likelihood score for number of cluster(s) 11: -3.9412921430876646
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 12364.910771404657
# AIC for number of cluster(s) 12: 12050.571719637781
# Log-likelihood score for number of cluster(s) 12: -3.9200301312870502
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 12348.722492985147
# AIC for number of cluster(s) 13: 12007.744538526164
# Log-likelihood score for number of cluster(s) 13: -3.902675603983628
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 12348.712444321995
# AIC for number of cluster(s) 14: 11981.095587170901
# Log-likelihood score for number of cluster(s) 14: -3.8906358696356445
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 12348.647184823116
# AIC for number of cluster(s) 15: 11954.391424979915
# Log-likelihood score for number of cluster(s) 15: -3.878577997693796
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 12333.28685244051
# AIC for number of cluster(s) 16: 11912.3921899052
# Log-likelihood score for number of cluster(s) 16: -3.861495463175164
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 12349.894460486057
# AIC for number of cluster(s) 17: 11902.36089525864
# Log-likelihood score for number of cluster(s) 17: -3.8549148801769513
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 12362.22781124906
# AIC for number of cluster(s) 18: 11888.055343329535
# Log-likelihood score for number of cluster(s) 18: -3.8469301390701496
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 12342.04974650038
# AIC for number of cluster(s) 19: 11841.238375888746
# Log-likelihood score for number of cluster(s) 19: -3.8282649066651597
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 12365.182217005215
# AIC for number of cluster(s) 20: 11837.731943701474
# Log-likelihood score for number of cluster(s) 20: -3.823827839586555
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 12358.656561792239
# AIC for number of cluster(s) 21: 11804.567385796388
# Log-likelihood score for number of cluster(s) 21: -3.8096476300250948
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 12374.251223707239
# AIC for number of cluster(s) 22: 11793.52314501928
# Log-likelihood score for number of cluster(s) 22: -3.802734278915664
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 12374.367071223169
# AIC for number of cluster(s) 23: 11767.000089843103
# Log-likelihood score for number of cluster(s) 23: -3.790735903365014
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 12401.866862723748
# AIC for number of cluster(s) 24: 11767.860978651574
# Log-likelihood score for number of cluster(s) 24: -3.7877335672311347
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 12420.432258750801
# AIC for number of cluster(s) 25: 11759.78747198652
# Log-likelihood score for number of cluster(s) 25: -3.7817961471703416
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 2: 17244.77712453144
# AIC for number of cluster(s) 2: 17186.171538608804
# Log-likelihood score for number of cluster(s) 2: -5.638689730160579
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 16324.753044536808
# AIC for number of cluster(s) 3: 16234.18077538364
# Log-likelihood score for number of cluster(s) 3: -5.322004196906583
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 15859.764275396365
# AIC for number of cluster(s) 4: 15737.225323012666
# Log-likelihood score for number of cluster(s) 4: -5.154804639623084
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 15467.964254434943
# AIC for number of cluster(s) 5: 15313.458618820716
# Log-likelihood score for number of cluster(s) 5: -5.011648692122443
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 15215.230652200473
# AIC for number of cluster(s) 6: 15028.758333355716
# Log-likelihood score for number of cluster(s) 6: -4.914178164702929
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 14975.804065048163
# AIC for number of cluster(s) 7: 14757.365062972876
# Log-likelihood score for number of cluster(s) 7: -4.82107919282946
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 14808.496239384698
# AIC for number of cluster(s) 8: 14558.09055407888
# Log-likelihood score for number of cluster(s) 8: -4.751672323941814
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 14622.39534752018
# AIC for number of cluster(s) 9: 14340.022978983834
# Log-likelihood score for number of cluster(s) 9: -4.676091648812035
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 14484.402408451799
# AIC for number of cluster(s) 10: 14170.063356684923
# Log-likelihood score for number of cluster(s) 10: -4.616315163168503
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 14384.357855798524
# AIC for number of cluster(s) 11: 14038.052120801118
# Log-likelihood score for number of cluster(s) 11: -4.56900529592678
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 14288.117685257208
# AIC for number of cluster(s) 12: 13909.845267029272
# Log-likelihood score for number of cluster(s) 12: -4.522945225699498
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 14253.10566444161
# AIC for number of cluster(s) 13: 13842.866562983143
# Log-likelihood score for number of cluster(s) 13: -4.496999527918247
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 14232.308274622614
# AIC for number of cluster(s) 14: 13790.102489933619
# Log-likelihood score for number of cluster(s) 14: -4.47572355122655
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 14200.625034199586
# AIC for number of cluster(s) 15: 13726.45256628006
# Log-likelihood score for number of cluster(s) 15: -4.450871408107773
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 14153.022188295916
# AIC for number of cluster(s) 16: 13646.88303714586
# Log-likelihood score for number of cluster(s) 16: -4.42078943401638
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 14135.774293292181
# AIC for number of cluster(s) 17: 13597.668458911596
# Log-likelihood score for number of cluster(s) 17: -4.40067952001038
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 14139.157813546812
# AIC for number of cluster(s) 18: 13569.085295935696
# Log-likelihood score for number of cluster(s) 18: -4.38734733769241
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 14113.695402059639
# AIC for number of cluster(s) 19: 13511.656201217995
# Log-likelihood score for number of cluster(s) 19: -4.364538830886332
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 14108.986843165309
# AIC for number of cluster(s) 20: 13474.980959093135
# Log-likelihood score for number of cluster(s) 20: -4.3485482782828955
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 14119.103644452536
# AIC for number of cluster(s) 21: 13453.131077149832
# Log-likelihood score for number of cluster(s) 21: -4.337428080535425
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 14109.880864775036
# AIC for number of cluster(s) 22: 13411.941614241801
# Log-likelihood score for number of cluster(s) 22: -4.319954538187188
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 14107.150022194019
# AIC for number of cluster(s) 23: 13377.244088430256
# Log-likelihood score for number of cluster(s) 23: -4.304613695279322
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 14071.929572942929
# AIC for number of cluster(s) 24: 13310.056955948636
# Log-likelihood score for number of cluster(s) 24: -4.278599525607305
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 14055.93938010655
# AIC for number of cluster(s) 25: 13262.100079881728
# Log-likelihood score for number of cluster(s) 25: -4.258902785769293
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 2: 20088.786584625675
# AIC for number of cluster(s) 2: 20019.525437626195
# Log-likelihood score for number of cluster(s) 2: -6.5681752423213515
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 18753.93768805502
# AIC for number of cluster(s) 3: 18647.382077286587
# Log-likelihood score for number of cluster(s) 3: -6.112806201473912
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 18001.93062808095
# AIC for number of cluster(s) 4: 17858.080553543565
# Log-likelihood score for number of cluster(s) 4: -5.848909511676598
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 17432.07007695268
# AIC for number of cluster(s) 5: 17250.925538646345
# Log-likelihood score for number of cluster(s) 5: -5.644850702577643
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 17128.18182567884
# AIC for number of cluster(s) 6: 16909.742823603552
# Log-likelihood score for number of cluster(s) 6: -5.5281678132731775
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 16720.215966718475
# AIC for number of cluster(s) 7: 16464.482500874234
# Log-likelihood score for number of cluster(s) 7: -5.377293857054611
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 16462.73148697602
# AIC for number of cluster(s) 8: 16169.703557362829
# Log-likelihood score for number of cluster(s) 8: -5.275855307937855
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 16219.44246717908
# AIC for number of cluster(s) 9: 15889.12007379694
# Log-likelihood score for number of cluster(s) 9: -5.179080181930663
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 16002.07964521096
# AIC for number of cluster(s) 10: 15634.462788059867
# Log-likelihood score for number of cluster(s) 10: -5.0908222036990365
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 15882.197568260823
# AIC for number of cluster(s) 11: 15477.286247340779
# Log-likelihood score for number of cluster(s) 11: -5.0345881233051175
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 15726.815300649065
# AIC for number of cluster(s) 12: 15284.60951596007
# Log-likelihood score for number of cluster(s) 12: -4.966691693810798
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 15641.98040244308
# AIC for number of cluster(s) 13: 15162.480153985132
# Log-likelihood score for number of cluster(s) 13: -4.921971141256614
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 15531.761205421464
# AIC for number of cluster(s) 14: 15014.966493194566
# Log-likelihood score for number of cluster(s) 14: -4.8689114629417105
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 15409.043475163338
# AIC for number of cluster(s) 15: 14854.954299167488
# Log-likelihood score for number of cluster(s) 15: -4.811745827584589
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 15347.050874248587
# AIC for number of cluster(s) 16: 14755.667234483786
# Log-likelihood score for number of cluster(s) 16: -4.774529314876408
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 15304.170159492605
# AIC for number of cluster(s) 17: 14675.492055958854
# Log-likelihood score for number of cluster(s) 17: -4.74359134558438
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 15300.266966665491
# AIC for number of cluster(s) 18: 14634.294399362787
# Log-likelihood score for number of cluster(s) 18: -4.725458081262413
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 15252.14648126577
# AIC for number of cluster(s) 19: 14548.879450194116
# Log-likelihood score for number of cluster(s) 19: -4.692798768132101
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 15222.64967304462
# AIC for number of cluster(s) 20: 14482.088178204012
# Log-likelihood score for number of cluster(s) 20: -4.66625761439028
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 15169.847451759557
# AIC for number of cluster(s) 21: 14391.991493149999
# Log-likelihood score for number of cluster(s) 21: -4.632060280272667
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 15119.20544183259
# AIC for number of cluster(s) 22: 14304.055019454081
# Log-likelihood score for number of cluster(s) 22: -4.598572608230644
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 15113.546491082448
# AIC for number of cluster(s) 23: 14261.101604934987
# Log-likelihood score for number of cluster(s) 23: -4.5798625508984845
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 15099.828656636408
# AIC for number of cluster(s) 24: 14210.089306719996
# Log-likelihood score for number of cluster(s) 24: -4.558505028488829
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 15089.00000649238
# AIC for number of cluster(s) 25: 14161.966192807016
# Log-likelihood score for number of cluster(s) 25: -4.538096646782857
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 2: 22740.93235052234
# AIC for number of cluster(s) 2: 22661.015642446015
# Log-likelihood score for number of cluster(s) 2: -7.434630631552567
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 20902.877080283546
# AIC for number of cluster(s) 3: 20780.33812789985
# Log-likelihood score for number of cluster(s) 3: -6.811543406011777
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 19913.007997533456
# AIC for number of cluster(s) 4: 19747.846800842384
# Log-likelihood score for number of cluster(s) 4: -6.46709816059211
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 19357.463586139802
# AIC for number of cluster(s) 5: 19149.68014514136
# Log-likelihood score for number of cluster(s) 5: -6.265335133095059
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 18892.067101295146
# AIC for number of cluster(s) 6: 18641.66141598933
# Log-likelihood score for number of cluster(s) 6: -6.093187061757336
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 18508.693824916747
# AIC for number of cluster(s) 7: 18215.66589530356
# Log-likelihood score for number of cluster(s) 7: -5.947984853910499
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 18118.53189001693
# AIC for number of cluster(s) 8: 17782.881716096366
# Log-likelihood score for number of cluster(s) 8: -5.800552469151238
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 17832.632467016287
# AIC for number of cluster(s) 9: 17454.360048788352
# Log-likelihood score for number of cluster(s) 9: -5.68737189513415
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 17526.927848438576
# AIC for number of cluster(s) 10: 17106.033185903267
# Log-likelihood score for number of cluster(s) 10: -5.567685015079917
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 17333.87469099716
# AIC for number of cluster(s) 11: 16870.35778415448
# Log-likelihood score for number of cluster(s) 11: -5.4850058423634955
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 17185.078061944085
# AIC for number of cluster(s) 12: 16678.93891079403
# Log-likelihood score for number of cluster(s) 12: -5.416865608013808
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 16988.34990606355
# AIC for number of cluster(s) 13: 16439.588510606125
# Log-likelihood score for number of cluster(s) 13: -5.33297914277468
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 16933.299897840414
# AIC for number of cluster(s) 14: 16341.916258075613
# Log-likelihood score for number of cluster(s) 14: -5.295636090037981
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 16785.478015665423
# AIC for number of cluster(s) 15: 16151.47213159325
# Log-likelihood score for number of cluster(s) 15: -5.227816074767822
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 16699.609160379056
# AIC for number of cluster(s) 16: 16022.981031999509
# Log-likelihood score for number of cluster(s) 16: -5.180348565045831
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 16557.42077274226
# AIC for number of cluster(s) 17: 15838.170400055342
# Log-likelihood score for number of cluster(s) 17: -5.114379237863122
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 16534.782259043906
# AIC for number of cluster(s) 18: 15772.909642049613
# Log-likelihood score for number of cluster(s) 18: -5.087683850870438
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 16450.812721484475
# AIC for number of cluster(s) 19: 15646.31786018281
# Log-likelihood score for number of cluster(s) 19: -5.040840295723656
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 16406.485631807
# AIC for number of cluster(s) 20: 15559.36852619796
# Log-likelihood score for number of cluster(s) 20: -5.007019883770684
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 16400.76469730959
# AIC for number of cluster(s) 21: 15511.025347393177
# Log-likelihood score for number of cluster(s) 21: -4.9858821771988096
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 16337.467714965569
# AIC for number of cluster(s) 22: 15405.106120741784
# Log-likelihood score for number of cluster(s) 22: -4.9458298688376425
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 16317.132784160163
# AIC for number of cluster(s) 23: 15342.148945629006
# Log-likelihood score for number of cluster(s) 23: -4.919891243636336
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 16250.651733871659
# AIC for number of cluster(s) 24: 15233.045651033128
# Log-likelihood score for number of cluster(s) 24: -4.878792920838741
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 16234.083954229041
# AIC for number of cluster(s) 25: 15173.855627083136
# Log-likelihood score for number of cluster(s) 25: -4.854091861722449
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 2: 24709.03305560184
# AIC for number of cluster(s) 2: 24618.460786448675
# Log-likelihood score for number of cluster(s) 2: -8.076366881224926
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: 22423.02724570965
# AIC for number of cluster(s) 3: 22284.50495171069
# Log-likelihood score for number of cluster(s) 3: -7.303713847473945
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: 21135.086774236526
# AIC for number of cluster(s) 4: 20948.61445539177
# Log-likelihood score for number of cluster(s) 4: -6.85894035985275
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: 20454.9062357461
# AIC for number of cluster(s) 5: 20220.48389205555
# Log-likelihood score for number of cluster(s) 5: -6.613825194499195
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: 19852.95674462948
# AIC for number of cluster(s) 6: 19570.58437609313
# Log-likelihood score for number of cluster(s) 6: -6.394410110411672
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: 19263.705826824866
# AIC for number of cluster(s) 7: 18933.383433442723
# Log-likelihood score for number of cluster(s) 7: -6.179166699554114
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: 18820.959098341908
# AIC for number of cluster(s) 8: 18442.686680113973
# Log-likelihood score for number of cluster(s) 8: -6.012052128815366
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: 18512.079893640577
# AIC for number of cluster(s) 9: 18085.857450566848
# Log-likelihood score for number of cluster(s) 9: -5.888915062604089
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: 18059.462825055874
# AIC for number of cluster(s) 10: 17585.29035713635
# Log-likelihood score for number of cluster(s) 10: -5.718557935984346
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: 17786.29936895846
# AIC for number of cluster(s) 11: 17264.176876193138
# Log-likelihood score for number of cluster(s) 11: -5.60715403291496
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 12: 17580.87927373769
# AIC for number of cluster(s) 12: 17010.806756126574
# Log-likelihood score for number of cluster(s) 12: -5.51800484761057
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 13: 17315.30760444218
# AIC for number of cluster(s) 13: 16697.28506198527
# Log-likelihood score for number of cluster(s) 13: -5.409094961230378
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 14: 17191.553843613467
# AIC for number of cluster(s) 14: 16525.581276310764
# Log-likelihood score for number of cluster(s) 14: -5.346774400890527
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 15: 17028.705405953402
# AIC for number of cluster(s) 15: 16314.782813804904
# Log-likelihood score for number of cluster(s) 15: -5.271610648424739
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 16: 16915.280764157058
# AIC for number of cluster(s) 16: 16153.408147162763
# Log-likelihood score for number of cluster(s) 16: -5.212683359777517
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 17: 16746.048719706963
# AIC for number of cluster(s) 17: 15936.226077866875
# Log-likelihood score for number of cluster(s) 17: -5.135422496014085
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 18: 16703.870599709353
# AIC for number of cluster(s) 18: 15846.09793302347
# Log-likelihood score for number of cluster(s) 18: -5.099900766433466
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 19: 16581.763266596343
# AIC for number of cluster(s) 19: 15676.040575064664
# Log-likelihood score for number of cluster(s) 19: -5.038121082478536
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 20: 16537.366943860117
# AIC for number of cluster(s) 20: 15583.694227482647
# Log-likelihood score for number of cluster(s) 20: -5.001870639777479
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 21: 16446.931652361607
# AIC for number of cluster(s) 21: 15445.308911138342
# Log-likelihood score for number of cluster(s) 21: -4.9504957001111505
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 22: 16316.976439756805
# AIC for number of cluster(s) 22: 15267.403673687744
# Log-likelihood score for number of cluster(s) 22: -4.8861378691484045
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 23: 16145.452705141062
# AIC for number of cluster(s) 23: 15047.929914226206
# Log-likelihood score for number of cluster(s) 23: -4.808124150534233
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 24: 16167.233550204965
# AIC for number of cluster(s) 24: 15021.760734444313
# Log-likelihood score for number of cluster(s) 24: -4.793613907504702
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 25: 16165.095811940042
# AIC for number of cluster(s) 25: 14971.672971333597
# Log-likelihood score for number of cluster(s) 25: -4.771246048401313
# ----------------------------------------------------------------------------------------------------

# %%
gm_bic_df.to_excel(r"cluster_analysis\cluster_analysis_bic_scores.xlsx", index=False)
gm_aic_df.to_excel(r"cluster_analysis\cluster_analysis_aic_scores.xlsx", index=False)
gm_score_df.to_excel(r"cluster_analysis\cluster_analysis_likelihood_scores.xlsx", index=False)

# %%
sns.set_theme(style="ticks", font_scale=1)

gm_bic_df.plot(x=gm_bic_df.columns[0]
               , y=gm_bic_df.columns[1:]
               , kind='line'
               , style=['-'
                        , '--'
                        , '-.'
                        , ':'
                        , '-'
                        , '--'
                        , '-.'
                        ]
               # , color=["#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #         ]  # All lines same color
               , linewidth=3
               # , title='Line Plots of Marks in Different Subjects'
               , ylabel = 'Normalized BIC scores'
               , xlabel = 'Number of clusters'
               # , fontsize = 'small'
              )
# Out:
# <Axes: xlabel='Number of clusters', ylabel='Normalized BIC scores'>

# %%
gm_aic_df.plot(x=gm_bic_df.columns[0]
               , y=gm_aic_df.columns[1:]
               , kind='line'
               , style=['-'
                        , '--'
                        , '-.'
                        , ':'
                        , '-'
                        , '--'
                        , '-.'
                        ]
               # , color=["#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #         ]  # All lines same color
               , linewidth=3
               # , title='Line Plots of Marks in Different Subjects'
               , ylabel = 'Normalized AIC scores'
               , xlabel = 'Number of clusters'
              )
# Out:
# <Axes: xlabel='Number of clusters', ylabel='Normalized AIC scores'>

# %%
gm_score_df.plot(x=gm_bic_df.columns[0]
               , y=gm_score_df.columns[1:]
               , kind='line'
               , style=['-'
                        , '--'
                        , '-.'
                        , ':'
                        , '-'
                        , '--'
                        , '-.'
                        ]
               # , color=["#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#1a1a1a"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #          , "#b3b3b3"
               #         ]  # All lines same color
               , linewidth=3
               # , title='Line Plots of Marks in Different Subjects'
               , ylabel = 'Normalized log-likelihood scores'
               , xlabel = 'Number of clusters'
              )
# Out:
# <Axes: xlabel='Number of clusters', ylabel='Normalized log-likelihood scores'>

# %% [markdown]
# ## conducting cluster analysis

# %%
# importing and setting up the clustering algorithm
from sklearn.mixture import GaussianMixture
clustering = GaussianMixture(n_components=7
                             , covariance_type='spherical'
                             , tol=0.0001
                             , reg_covar=1e-06
                             , max_iter=1000
                             , n_init=1000
                             , init_params='k-means++'
                             , weights_init=None
                             , means_init=None
                             , precisions_init=None
                             , random_state=None
                             , warm_start=False
                             , verbose=0
                             , verbose_interval=10
                            )

# %%
# clustering
clust = clustering.fit_predict(pca_df[pca_df.columns[:2]])

# %%
WDI_GFDI_df['Cluster index ID'] = clust

# %%
WDI_GFDI_df.to_excel(r"cluster_analysis\data_with_clusters.xlsx", index=False)
